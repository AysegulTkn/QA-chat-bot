# %% [markdown]
# # QA Bot

# %% [markdown]
#  ## AI RAG Assistant Using LangChain

# %%
# first installing necessary packages

#for user interface
! pip install gradio==4.44.0 

#for generative llm model and embedding model
! pip install ibm-watsonx-ai==1.1.2  

#for using relevant features from LangChain
! pip install langchain==0.2.11 
! pip install langchain-community==0.2.10 
! pip install langchain-ibm==0.1.11 

#to construct vectordatabase 
! pip install chromadb==0.4.24  

! pip install pypdf==4.3.1 
! pip install pydantic==2.9.1
# Out:
# Requirement already satisfied: gradio==4.44.0 in c:\users\gamer\anaconda3\lib\site-packages (4.44.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (4.2.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.115.12)
# Requirement already satisfied: ffmpy in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.5.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.29.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (3.8.4)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (1.26.0)
# Requirement already satisfied: orjson~=3.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (3.10.14)
# Requirement already satisfied: packaging in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (2.9.1)
# Requirement already satisfied: pydub in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.11.9)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio==4.44.0) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\gamer\anaconda3\lib\site-packages (from gradio-client==1.3.0->gradio==4.44.0) (2023.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\gamer\anaconda3\lib\site-packages (from gradio-client==1.3.0->gradio==4.44.0) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\gamer\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio==4.44.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gamer\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio==4.44.0) (1.3.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\gamer\anaconda3\lib\site-packages (from fastapi<1.0->gradio==4.44.0) (0.46.2)
# Requirement already satisfied: certifi in c:\users\gamer\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio==4.44.0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\gamer\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio==4.44.0) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.44.0) (0.14.0)
# Requirement already satisfied: filelock in c:\users\gamer\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.44.0) (3.13.1)
# Requirement already satisfied: requests in c:\users\gamer\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.44.0) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\gamer\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.44.0) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.44.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.44.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic>=2.0->gradio==4.44.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic>=2.0->gradio==4.44.0) (2.23.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (13.3.5)
# Requirement already satisfied: colorama in c:\users\gamer\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio==4.44.0) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\gamer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.44.0) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gamer\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.44.0) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gamer\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (0.1.0)
# Requirement already satisfied: ibm-watsonx-ai==1.1.2 in c:\users\gamer\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: requests in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2.32.2)
# Requirement already satisfied: urllib3 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2.0.7)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2.1.4)
# Requirement already satisfied: certifi in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2025.4.26)
# Requirement already satisfied: lomond in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (0.3.3)
# Requirement already satisfied: tabulate in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (0.9.0)
# Requirement already satisfied: packaging in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.1.2) (7.0.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (1.26.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai==1.1.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamer\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai==1.1.2) (3.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\gamer\anaconda3\lib\site-packages (from importlib-metadata->ibm-watsonx-ai==1.1.2) (3.17.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\gamer\anaconda3\lib\site-packages (from lomond->ibm-watsonx-ai==1.1.2) (1.16.0)
# Requirement already satisfied: langchain==0.2.11 in c:\users\gamer\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (3.9.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (1.26.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain==0.2.11) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.11) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.11) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.11) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.11) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.11) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.11) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gamer\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.11) (3.0.1)
# Requirement already satisfied: anyio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gamer\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (2.1)
# Requirement already satisfied: langchain-community==0.2.10 in c:\users\gamer\anaconda3\lib\site-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.9 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (0.2.11)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (1.26.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-community==0.2.10) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gamer\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\gamer\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\gamer\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\gamer\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (2.9.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.10) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.10) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.10) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gamer\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.10) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gamer\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.10) (3.0.1)
# Requirement already satisfied: anyio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gamer\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (2.23.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (1.0.0)
# Requirement already satisfied: langchain-ibm==0.1.11 in c:\users\gamer\anaconda3\lib\site-packages (0.1.11)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.0.8 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-ibm==0.1.11) (1.1.2)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-ibm==0.1.11) (0.2.43)
# Requirement already satisfied: requests in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.32.2)
# Requirement already satisfied: urllib3 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.0.7)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.1.4)
# Requirement already satisfied: certifi in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2025.4.26)
# Requirement already satisfied: lomond in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (0.3.3)
# Requirement already satisfied: tabulate in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (0.9.0)
# Requirement already satisfied: packaging in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\users\gamer\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (7.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.1.147)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (2.9.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\gamer\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (4.12.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\gamer\anaconda3\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gamer\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.26.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamer\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (3.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\gamer\anaconda3\lib\site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (3.17.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\gamer\anaconda3\lib\site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.16.0)
# Requirement already satisfied: anyio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\gamer\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.14.0)
# Requirement already satisfied: chromadb==0.4.24 in c:\users\gamer\anaconda3\lib\site-packages (0.4.24)
# Requirement already satisfied: build>=1.0.3 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.2.2.post1)
# Requirement already satisfied: requests>=2.28 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (2.32.2)
# Requirement already satisfied: pydantic>=1.9 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (2.9.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.115.12)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.26.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (4.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (4.12.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (3.6.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.33.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.33.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.54b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.33.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (0.15.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\gamer\anaconda3\lib\site-packages (from chromadb==0.4.24) (3.10.14)
# Requirement already satisfied: packaging>=19.1 in c:\users\gamer\anaconda3\lib\site-packages (from build>=1.0.3->chromadb==0.4.24) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\gamer\anaconda3\lib\site-packages (from build>=1.0.3->chromadb==0.4.24) (1.2.0)
# Requirement already satisfied: colorama in c:\users\gamer\anaconda3\lib\site-packages (from build>=1.0.3->chromadb==0.4.24) (0.4.6)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\gamer\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb==0.4.24) (0.46.2)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (2025.4.26)
# Requirement already satisfied: six>=1.9.0 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (2.40.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (2.0.7)
# Requirement already satisfied: durationpy>=0.7 in c:\users\gamer\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.4.24) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\gamer\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.24) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\gamer\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.24) (25.1.24)
# Requirement already satisfied: protobuf in c:\users\gamer\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.24) (5.29.4)
# Requirement already satisfied: sympy in c:\users\gamer\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.24) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.24) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.24) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.24) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.24) (1.33.0)
# Requirement already satisfied: opentelemetry-proto==1.33.0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.24) (1.33.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (0.54b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (0.54b0)
# Requirement already satisfied: opentelemetry-util-http==0.54b0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (0.54b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\gamer\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.24) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\gamer\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.24) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\gamer\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.24) (1.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb==0.4.24) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb==0.4.24) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gamer\anaconda3\lib\site-packages (from requests>=2.28->chromadb==0.4.24) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamer\anaconda3\lib\site-packages (from requests>=2.28->chromadb==0.4.24) (3.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\gamer\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb==0.4.24) (0.29.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb==0.4.24) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb==0.4.24) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gamer\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb==0.4.24) (13.3.5)
# Requirement already satisfied: h11>=0.8 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.24) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\gamer\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gamer\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.24) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gamer\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.24) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gamer\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.24) (4.9.1)
# Requirement already satisfied: filelock in c:\users\gamer\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\gamer\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\gamer\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.4.24) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.24) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gamer\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.24) (2.15.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\gamer\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi>=0.95.2->chromadb==0.4.24) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\gamer\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.24) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gamer\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.24) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gamer\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.95.2->chromadb==0.4.24) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\gamer\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.24) (3.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gamer\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.4.24) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gamer\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.24) (0.4.8)
# Requirement already satisfied: pypdf==4.3.1 in c:\users\gamer\anaconda3\lib\site-packages (4.3.1)
# Requirement already satisfied: pydantic==2.9.1 in c:\users\gamer\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic==2.9.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic==2.9.1) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gamer\anaconda3\lib\site-packages (from pydantic==2.9.1) (4.12.2)

# %%
#import all required libraries in one place
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.metanames import EmbedTextParamsMetaNames
from ibm_watsonx_ai import Credentials
from langchain_ibm import WatsonxLLM, WatsonxEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain.chains import RetrievalQA
import gradio as gr

# %%
# to suppress warnings generated by code
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
# following function defines the foundational LLM

def get_llm():
    model_id = 'mistralai/mixtral-8x7b-instruct-v01'
    # mixtral-8x7b-instruct-v01 is used as the base foundational LLM
    parameters = {
        GenParams.MAX_NEW_TOKENS: 256,  # maximum number of tokens in the generated output
        GenParams.TEMPERATURE: 0.5,  # randomness or creativity of the model's responses
    }
    project_id="b0f04176-fca0-442c-8ec6-a1a07eaf8527"
    #project_id = "skills-network"
    watsonx_llm = WatsonxLLM(
        model_id=model_id,
        url="https://eu-de.ml.cloud.ibm.com",
        apikey="lwjvBy9RyXnm6EdF-ZMmom4ENB5JMYjo5wVDyiA507kd",
        #url="https://us-south.ml.cloud.ibm.com",
        project_id=project_id,
        params=parameters,
    )
    return watsonx_llm

# %%
# this function takes the pdf file and loads the  document
def document_loader(file):
    loader = PyPDFLoader(file.name)
    loaded_document = loader.load()
    return loaded_document

# %%
#to split document, text_splitter uses recursive character splitter which is more effective for generic text
def text_splitter(data):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000, #controlls chunk size
        chunk_overlap=50, #size of overlab between chunks
        length_function=len, 
    )
    chunks = text_splitter.split_documents(data)
    return chunks

# %%
# function that embeds the chunks using a defined embedding model and stores the embeddings in a ChromaDB vector store
def vector_database(chunks):
    embedding_model = watsonx_embedding()
    vectordb = Chroma.from_documents(chunks, embedding_model) #Store the document's embeddings into a vector database
    return vectordb

# %%
# Embedding model 
# needs to convert chunks of text into vector representations
def watsonx_embedding():
    embed_params = {
        EmbedTextParamsMetaNames.TRUNCATE_INPUT_TOKENS: 3,
        EmbedTextParamsMetaNames.RETURN_OPTIONS: {"input_text": True},
    }
    watsonx_embedding = WatsonxEmbeddings(
        model_id="ibm/slate-125m-english-rtrvr", #ibm/slate-125m-english-rtrvr embedding model is used
        url='https://eu-de.ml.cloud.ibm.com',
        #url="https://us-south.ml.cloud.ibm.com",
        #project_id="skills-network",
        project_id='b0f04176-fca0-442c-8ec6-a1a07eaf8527', 
        apikey="lwjvBy9RyXnm6EdF-ZMmom4ENB5JMYjo5wVDyiA507kd",
        params=embed_params,
    )
    return watsonx_embedding

# %%
# an interface designed to return documents based on an unstructured query
def retriever(file):
    splits = document_loader(file)
    chunks = text_splitter(splits)
    vectordb = vector_database(chunks)
    retriever = vectordb.as_retriever() #a vector store-based retriever that retrieves information using a simple similarity search
    return retriever

# %%
# QA Chain
#that performs natural-language question-answering over a data source using retrieval-augmented generation (RAG)
def retriever_qa(file, query):
    llm = get_llm()
    retriever_obj = retriever(file)
    #use RetrievalQA from langchain
    qa = RetrievalQA.from_chain_type(llm=llm, 
                                    chain_type="stuff", 
                                    retriever=retriever_obj, 
                                    return_source_documents=False)
    response = qa.invoke(query)
    return response['result']

# %%
# Create Gradio interface
rag_application = gr.Interface(
    fn=retriever_qa,
    allow_flagging="never",
    inputs=[
        gr.File(label="Upload PDF File", file_count="single", file_types=['.pdf'], type="filepath"),  # Drag and drop file upload
        gr.Textbox(label="Input Query", lines=2, placeholder="Type your question here...") #an input textbox where the question can be asked
    ],
    outputs=gr.Textbox(label="Output"), #an output textbox where the question can be answered
    title="RAG Chatbot",
    description="Upload a PDF document and ask any question. The chatbot will try to answer using the provided document."
)

# %%
# Launch the app with the following line of code
import random
port = random.randint(3000, 5000)
rag_application.launch(server_name="0.0.0.0", server_port= port)
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:2860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
